# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
weather = './datasets/weather.csv'
weather = pd.read_csv(weather)

# %%
weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
# Station        2944 non-null int64
# Date           2944 non-null object
# Tmax           2944 non-null int64
# Tmin           2944 non-null int64
# Tavg           2944 non-null object
# Depart         2944 non-null object
# DewPoint       2944 non-null int64
# WetBulb        2944 non-null object
# Heat           2944 non-null object
# Cool           2944 non-null object
# Sunrise        2944 non-null object
# Sunset         2944 non-null object
# CodeSum        2944 non-null object
# Depth          2944 non-null object
# Water1         2944 non-null object
# SnowFall       2944 non-null object
# PrecipTotal    2944 non-null object
# StnPressure    2944 non-null object
# SeaLevel       2944 non-null object
# ResultSpeed    2944 non-null float64
# ResultDir      2944 non-null int64
# AvgSpeed       2944 non-null object
# dtypes: float64(1), int64(5), object(16)
# ...

# %%
weather.SnowFall.unique()
# Out:
# array(['0.0', 'M', '  T', '0.1'], dtype=object)

# %%
weather.Tavg.unique()
# Out:
# array(['67', '68', '51', '52', '56', '58', 'M', '60', '59', '65', '70',
#        '69', '71', '61', '55', '57', '73', '72', '53', '62', '63', '74',
#        '75', '78', '76', '77', '66', '80', '64', '81', '82', '79', '85',
#        '84', '83', '50', '49', '46', '48', '45', '54', '47', '44', '40',
#        '41', '38', '39', '42', '37', '43', '86', '87', '89', '92', '88',
#        '91', '93', '94', '90', '36'], dtype=object)

# %%
weather['Tavg'] = (weather['Tmax'] + weather['Tmin'])/2

# %%
weather.Tavg.unique()
# Out:
# array([66.5, 68. , 50.5, 51.5, 56. , 57.5, 64.5, 59.5, 60. , 58.5, 65. ,
#        67. , 70. , 69. , 69.5, 71. , 60.5, 61. , 55. , 56.5, 73. , 72. ,
#        68.5, 54.5, 52.5, 62. , 62.5, 73.5, 74.5, 77.5, 75.5, 77. , 63. ,
#        61.5, 57. , 66. , 74. , 76.5, 79.5, 71.5, 70.5, 64. , 55.5, 81. ,
#        81.5, 65.5, 75. , 72.5, 78.5, 78. , 80. , 80.5, 79. , 82. , 63.5,
#        67.5, 76. , 84.5, 84. , 82.5, 50. , 52. , 48.5, 51. , 49.5, 59. ,
#        49. , 46. , 48. , 45. , 53.5, 54. , 53. , 47. , 58. , 46.5, 43.5,
#        40. , 40.5, 38. , 38.5, 41.5, 42. , 83.5, 83. , 45.5, 39.5, 36.5,
#        37. , 44.5, 42.5, 43. , 44. , 47.5, 85.5, 86.5, 86. , 87. , 88.5,
#        91.5, 85. , 88. , 89. , 90.5, 91. , 92.5, 93.5, 87.5, 89.5, 41. ,
#        35.5, 36. , 39. , 37.5])

# %%
weather
# Out:
#       Station        Date  Tmax  Tmin  Tavg Depart  DewPoint WetBulb Heat  \
# 0           1  2007-05-01    83    50  66.5     14        51      56    0
# 1           2  2007-05-01    84    52  68.0      M        51      57    0
# 2           1  2007-05-02    59    42  50.5     -3        42      47   14
# 3           2  2007-05-02    60    43  51.5      M        42      47   13
# 4           1  2007-05-03    66    46  56.0      2        40      48    9
# 5           2  2007-05-03    67    48  57.5      M        40      50    7
# 6           1  2007-05-04    66    49  57.5      4        41      50    7
# 7           2  2007-05-04    78    51  64.5      M        42      50    M
# 8           1  2007-05-05    66    53  59.5      5        38      49    5
# 9           2  2007-05-05    66    54  60.0      M        39      50    5
# 10          1  2007-05-06    68    49  58.5      4        30      46    6
# 11          2  2007-05-06    68    52  60.0      M        30      46    5
# ...

# %%
weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg           float64
# Depart          object
# DewPoint         int64
# WetBulb         object
# Heat            object
# Cool            object
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
weather.Depart.unique()
# Out:
# array(['14', 'M', '-3', ' 2', ' 4', ' 5', '10', '12', '13', '-2', '15',
#        '11', '-4', '-6', ' 8', '-5', ' 1', ' 9', ' 6', '-9', '-8', ' 3',
#        ' 0', '-1', '-7', ' 7', '-14', '18', '16', '22', '21', '20', '-10',
#        '-16', '17', '-12', '-11', '-15', '-17', '19', '-13', '23'],
#       dtype=object)

# %%
weather.drop(labels = 'Depart', axis= 1, inplace = True)

# %%
weather
# Out:
#       Station        Date  Tmax  Tmin  Tavg  DewPoint WetBulb Heat Cool  \
# 0           1  2007-05-01    83    50  66.5        51      56    0    2
# 1           2  2007-05-01    84    52  68.0        51      57    0    3
# 2           1  2007-05-02    59    42  50.5        42      47   14    0
# 3           2  2007-05-02    60    43  51.5        42      47   13    0
# 4           1  2007-05-03    66    46  56.0        40      48    9    0
# 5           2  2007-05-03    67    48  57.5        40      50    7    0
# 6           1  2007-05-04    66    49  57.5        41      50    7    0
# 7           2  2007-05-04    78    51  64.5        42      50    M    M
# 8           1  2007-05-05    66    53  59.5        38      49    5    0
# 9           2  2007-05-05    66    54  60.0        39      50    5    0
# 10          1  2007-05-06    68    49  58.5        30      46    6    0
# 11          2  2007-05-06    68    52  60.0        30      46    5    0
# ...

# %%
weather.DewPoint.unique()
# Out:
# array([51, 42, 40, 41, 38, 39, 30, 58, 57, 59, 60, 52, 44, 36, 37, 33, 32,
#        47, 45, 56, 43, 31, 50, 46, 49, 48, 54, 53, 55, 61, 63, 62, 64, 65,
#        66, 67, 69, 70, 68, 71, 72, 73, 35, 34, 29, 27, 28, 23, 24, 25, 22,
#        26, 75, 74], dtype=int64)

# %%
weather.WetBulb.unique()
# Out:
# array(['56', '57', '47', '48', '50', '49', '46', '54', '53', '62', '63',
#        '60', '61', '51', '59', '58', '43', '44', '45', '65', '66', '67',
#        '64', '52', '55', '69', '68', '70', '72', '71', '73', '74', '76',
#        '42', '39', '40', '41', '35', '33', '34', 'M', '75', '36', '32',
#        '38', '78', '77', '37'], dtype=object)

# %%
weather[weather['WetBulb'] == 'M']
# Out:
#       Station        Date  Tmax  Tmin  Tavg  DewPoint WetBulb Heat Cool  \
# 848         1  2009-06-26    86    69  77.5        60       M    0   13
# 2410        1  2013-08-10    81    64  72.5        57       M    0    8
# 2412        1  2013-08-11    81    60  70.5        61       M    0    6
# 2415        2  2013-08-12    85    69  77.0        63       M    0   12
#
#      Sunrise    ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 848     0418    ...                0      M      0.0        0.00           M
# 2410    0454    ...                0      M      0.0        0.00           M
# 2412    0455    ...         RA     0      M      0.0        0.01       29.35
# 2415       -    ...         RA     M      M        M        0.66       29.27
#
#      SeaLevel ResultSpeed  ResultDir  AvgSpeed
# 848     29.85         6.4          4       8.2
# 2410    30.08         5.3          5       6.5
# 2412    30.07         2.0         27       3.0
# ...

# %%
weather.loc[848, 'WetBulb'] = np.nan
weather.loc[2410, 'WetBulb'] = np.nan
weather.loc[2412, 'WetBulb'] = np.nan
weather.loc[2415, 'WetBulb'] = np.nan

# %%
weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg           float64
# DewPoint         int64
# WetBulb         object
# Heat            object
# Cool            object
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
weather[['WetBulb']] = weather[['WetBulb']].apply(pd.to_numeric)

# %%
wb_mean = weather['WetBulb'].mean()
wb_mean
# Out:
# 59.3108843537415

# %%
weather.loc[848, 'WetBulb'] = wb_mean
weather.loc[2410, 'WetBulb'] = wb_mean
weather.loc[2412, 'WetBulb'] = wb_mean
weather.loc[2415, 'WetBulb'] = wb_mean

# %%
weather.WetBulb.unique()
# Out:
# array([56.        , 57.        , 47.        , 48.        , 50.        ,
#        49.        , 46.        , 54.        , 53.        , 62.        ,
#        63.        , 60.        , 61.        , 51.        , 59.        ,
#        58.        , 43.        , 44.        , 45.        , 65.        ,
#        66.        , 67.        , 64.        , 52.        , 55.        ,
#        69.        , 68.        , 70.        , 72.        , 71.        ,
#        73.        , 74.        , 76.        , 42.        , 39.        ,
#        40.        , 41.        , 35.        , 33.        , 34.        ,
#        59.31088435, 75.        , 36.        , 32.        , 38.        ,
#        78.        , 77.        , 37.        ])

# %%
weather.Heat.unique()
# Out:
# array(['0', '14', '13', '9', '7', 'M', '5', '6', '4', '10', '8', '12',
#        '3', '2', '1', '15', '16', '19', '17', '20', '11', '18', '21',
#        '25', '24', '27', '26', '23', '28', '22', '29'], dtype=object)

# %%
weather[weather['Heat'] == 'M']
# Out:
#       Station        Date  Tmax  Tmin  Tavg  DewPoint  WetBulb Heat Cool  \
# 7           2  2007-05-04    78    51  64.5        42     50.0    M    M
# 505         2  2008-07-08    86    46  66.0        68     71.0    M    M
# 675         2  2008-10-01    62    46  54.0        41     47.0    M    M
# 1637        2  2011-07-22   100    71  85.5        70     74.0    M    M
# 2067        2  2012-08-22    84    72  78.0        51     61.0    M    M
# 2211        2  2013-05-02    71    42  56.5        39     45.0    M    M
# 2501        2  2013-09-24    91    52  71.5        48     54.0    M    M
# 2511        2  2013-09-29    84    53  68.5        48     54.0    M    M
# 2525        2  2013-10-06    76    48  62.0        44     50.0    M    M
# 2579        2  2014-05-02    80    47  63.5        43     47.0    M    M
# 2811        2  2014-08-26    86    49  67.5        68     71.0    M    M
#
#      Sunrise    ...        CodeSum Depth Water1 SnowFall PrecipTotal  \
# ...

# %%
weather.loc[7, 'Heat'] = np.nan
weather.loc[505, 'Heat'] = np.nan
weather.loc[675, 'Heat'] = np.nan
weather.loc[1637, 'Heat'] = np.nan
weather.loc[2067, 'Heat'] = np.nan
weather.loc[2211, 'Heat'] = np.nan
weather.loc[2501, 'Heat'] = np.nan

weather.loc[2511, 'Heat'] = np.nan

weather.loc[2525, 'Heat'] = np.nan

weather.loc[2579, 'Heat'] = np.nan

weather.loc[2811, 'Heat'] = np.nan

# %%
weather[['Heat']] = weather[['Heat']].apply(pd.to_numeric)

# %%
weather['Heat'].unique()
# Out:
# array([ 0., 14., 13.,  9.,  7., nan,  5.,  6.,  4., 10.,  8., 12.,  3.,
#         2.,  1., 15., 16., 19., 17., 20., 11., 18., 21., 25., 24., 27.,
#        26., 23., 28., 22., 29.])

# %%
h_mean = weather['Heat'].mean()
h_mean
# Out:
# 3.40709171496761

# %%
weather.loc[7, 'Heat'] = h_mean
weather.loc[505, 'Heat'] = h_mean
weather.loc[675, 'Heat'] = h_mean
weather.loc[1637, 'Heat'] = h_mean
weather.loc[2067, 'Heat'] = h_mean
weather.loc[2211, 'Heat'] = h_mean
weather.loc[2501, 'Heat'] = h_mean

weather.loc[2511, 'Heat'] = h_mean

weather.loc[2525, 'Heat'] = h_mean

weather.loc[2579, 'Heat'] = h_mean

weather.loc[2811, 'Heat'] = h_mean

# %%
weather['Heat'].unique()
# Out:
# array([ 0.        , 14.        , 13.        ,  9.        ,  7.        ,
#         3.40709171,  5.        ,  6.        ,  4.        , 10.        ,
#         8.        , 12.        ,  3.        ,  2.        ,  1.        ,
#        15.        , 16.        , 19.        , 17.        , 20.        ,
#        11.        , 18.        , 21.        , 25.        , 24.        ,
#        27.        , 26.        , 23.        , 28.        , 22.        ,
#        29.        ])

# %%
weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg           float64
# DewPoint         int64
# WetBulb        float64
# Heat           float64
# Cool            object
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
weather.Sunrise.unique()
# Out:
# array(['0448', '-', '0447', '0446', '0444', '0443', '0442', '0441',
#        '0439', '0438', '0437', '0436', '0435', '0434', '0433', '0432',
#        '0431', '0430', '0429', '0428', '0427', '0426', '0425', '0424',
#        '0423', '0422', '0421', '0420', '0419', '0418', '0417', '0416',
#        '0440', '0445', '0449', '0450', '0451', '0452', '0453', '0454',
#        '0455', '0456', '0457', '0458', '0459', '0500', '0501', '0502',
#        '0503', '0504', '0505', '0506', '0508', '0509', '0510', '0511',
#        '0512', '0513', '0514', '0515', '0516', '0517', '0518', '0519',
#        '0520', '0521', '0522', '0523', '0524', '0525', '0526', '0527',
#        '0528', '0529', '0530', '0531', '0532', '0533', '0535', '0536',
#        '0537', '0538', '0539', '0540', '0541', '0542', '0543', '0544',
#        '0545', '0546', '0547', '0548', '0549', '0550', '0552', '0553',
#        '0554', '0555', '0556', '0557', '0558', '0559', '0600', '0602',
# ...

# %%
weather[weather['Sunrise'] == '-']
# Out:
#       Station        Date  Tmax  Tmin  Tavg  DewPoint  WetBulb       Heat  \
# 1           2  2007-05-01    84    52  68.0        51     57.0   0.000000
# 3           2  2007-05-02    60    43  51.5        42     47.0  13.000000
# 5           2  2007-05-03    67    48  57.5        40     50.0   7.000000
# 7           2  2007-05-04    78    51  64.5        42     50.0   3.407092
# 9           2  2007-05-05    66    54  60.0        39     50.0   5.000000
# 11          2  2007-05-06    68    52  60.0        30     46.0   5.000000
# 13          2  2007-05-07    84    50  67.0        39     53.0   0.000000
# 15          2  2007-05-08    80    60  70.0        57     63.0   0.000000
# 17          2  2007-05-09    76    63  69.5        60     63.0   0.000000
# 19          2  2007-05-10    83    59  71.0        52     61.0   0.000000
# 21          2  2007-05-11    73    49  61.0        44     51.0   4.000000
# 23          2  2007-05-12    65    47  56.0        37     46.0   9.000000
# ...

# %%
weather[weather['Sunset'] == '-']
# Out:
#       Station        Date  Tmax  Tmin  Tavg  DewPoint  WetBulb       Heat  \
# 1           2  2007-05-01    84    52  68.0        51     57.0   0.000000
# 3           2  2007-05-02    60    43  51.5        42     47.0  13.000000
# 5           2  2007-05-03    67    48  57.5        40     50.0   7.000000
# 7           2  2007-05-04    78    51  64.5        42     50.0   3.407092
# 9           2  2007-05-05    66    54  60.0        39     50.0   5.000000
# 11          2  2007-05-06    68    52  60.0        30     46.0   5.000000
# 13          2  2007-05-07    84    50  67.0        39     53.0   0.000000
# 15          2  2007-05-08    80    60  70.0        57     63.0   0.000000
# 17          2  2007-05-09    76    63  69.5        60     63.0   0.000000
# 19          2  2007-05-10    83    59  71.0        52     61.0   0.000000
# 21          2  2007-05-11    73    49  61.0        44     51.0   4.000000
# 23          2  2007-05-12    65    47  56.0        37     46.0   9.000000
# ...

# %%
weather[weather['Cool'] == 'M']
# Out:
#       Station        Date  Tmax  Tmin  Tavg  DewPoint  WetBulb      Heat Cool  \
# 7           2  2007-05-04    78    51  64.5        42     50.0  3.407092    M
# 505         2  2008-07-08    86    46  66.0        68     71.0  3.407092    M
# 675         2  2008-10-01    62    46  54.0        41     47.0  3.407092    M
# 1637        2  2011-07-22   100    71  85.5        70     74.0  3.407092    M
# 2067        2  2012-08-22    84    72  78.0        51     61.0  3.407092    M
# 2211        2  2013-05-02    71    42  56.5        39     45.0  3.407092    M
# 2501        2  2013-09-24    91    52  71.5        48     54.0  3.407092    M
# 2511        2  2013-09-29    84    53  68.5        48     54.0  3.407092    M
# 2525        2  2013-10-06    76    48  62.0        44     50.0  3.407092    M
# 2579        2  2014-05-02    80    47  63.5        43     47.0  3.407092    M
# 2811        2  2014-08-26    86    49  67.5        68     71.0  3.407092    M
#
# ...

# %%
weather['Cool'] = weather['Cool'].map(lambda x: int(x) if x != 'M' else np.NaN)

# %%
weather['Cool'].unique()
# Out:
# array([ 2.,  3.,  0., nan,  5.,  4.,  6.,  8.,  7.,  9., 10., 13., 11.,
#        12.,  1., 15., 16., 17., 14., 20., 19., 18., 21., 22., 24., 27.,
#        23., 26., 28., 29., 25.])

# %%
weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg           float64
# DewPoint         int64
# WetBulb        float64
# Heat           float64
# Cool           float64
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
c_mean = weather['Cool'].mean()
c_mean
# Out:
# 5.647118990794408

# %%
# evergreen['is_news'] = evergreen['is_news'].map(lambda x: 0 if x == "?" else 1)
# weather['Cool'] = weather['Cool'].map(lambda x: float(x) if x != 'nan' else c_mean)
# weather

weather.loc[7, 'Cool'] = c_mean
weather.loc[505, 'Cool'] = c_mean
weather.loc[675, 'Cool'] = c_mean
weather.loc[1637, 'Cool'] = c_mean
weather.loc[2067, 'Cool'] = c_mean
weather.loc[2211, 'Cool'] = c_mean
weather.loc[2501, 'Cool'] = c_mean

weather.loc[2511, 'Cool'] = c_mean

weather.loc[2525, 'Cool'] = c_mean

weather.loc[2579, 'Cool'] = c_mean

weather.loc[2811, 'Cool'] = c_mean

# %%
weather['Cool'].unique()
# Out:
# array([ 2.        ,  3.        ,  0.        ,  5.64711899,  5.        ,
#         4.        ,  6.        ,  8.        ,  7.        ,  9.        ,
#        10.        , 13.        , 11.        , 12.        ,  1.        ,
#        15.        , 16.        , 17.        , 14.        , 20.        ,
#        19.        , 18.        , 21.        , 22.        , 24.        ,
#        27.        , 23.        , 26.        , 28.        , 29.        ,
#        25.        ])

# %%
weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg           float64
# DewPoint         int64
# WetBulb        float64
# Heat           float64
# Cool           float64
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
# crime.Dates = pd.to_datetime(crime.Dates)
weather.Date = pd.to_datetime(weather.Date)

# %%
# weather['Hour'] = weather.Date.dt.hour
weather['Month'] = weather.Date.dt.month
weather['Year'] = weather.Date.dt.year
weather['Dates'] = weather.Date.dt.date

# %%
weather
# Out:
#       Station       Date  Tmax  Tmin  Tavg  DewPoint  WetBulb       Heat  \
# 0           1 2007-05-01    83    50  66.5        51     56.0   0.000000
# 1           2 2007-05-01    84    52  68.0        51     57.0   0.000000
# 2           1 2007-05-02    59    42  50.5        42     47.0  14.000000
# 3           2 2007-05-02    60    43  51.5        42     47.0  13.000000
# 4           1 2007-05-03    66    46  56.0        40     48.0   9.000000
# 5           2 2007-05-03    67    48  57.5        40     50.0   7.000000
# 6           1 2007-05-04    66    49  57.5        41     50.0   7.000000
# 7           2 2007-05-04    78    51  64.5        42     50.0   3.407092
# 8           1 2007-05-05    66    53  59.5        38     49.0   5.000000
# 9           2 2007-05-05    66    54  60.0        39     50.0   5.000000
# 10          1 2007-05-06    68    49  58.5        30     46.0   6.000000
# 11          2 2007-05-06    68    52  60.0        30     46.0   5.000000
# ...

# %%
weather.PrecipTotal.value_counts()
# Out:
# 0.00    1577
#   T      318
# 0.01     127
# 0.02      63
# 0.03      46
# 0.04      36
# 0.05      32
# 0.08      28
# 0.12      28
# 0.06      27
# 0.07      23
# 0.09      21
# 0.16      21
# 0.14      20
# 0.11      20
# 0.17      17
# 0.28      15
# 0.18      14
# 0.13      14
# 0.19      14
# 0.20      13
# 0.15      13
# 0.25      11
# 0.23      11
# 0.26      11
# 0.10      10
# 0.24      10
# 0.29       9
# 0.43       9
# 0.31       9
#         ...
# 0.62       1
# 2.03       1
# 2.68       1
# 2.60       1
# 1.49       1
# 1.48       1
# 3.31       1
# 1.44       1
# 1.46       1
# 6.86       1
# 1.82       1
# 1.60       1
# 2.35       1
# 2.20       1
# 2.24       1
# 1.57       1
# 6.64       1
# 3.15       1
# 3.17       1
# 1.96       1
# 0.76       1
# 1.34       1
# 0.91       1
# 1.73       1
# 3.07       1
# 1.90       1
# 2.43       1
# 2.90       1
# 1.35       1
# 1.24       1
# Name: PrecipTotal, Length: 168, dtype: int64

# %%
weather['PrecipTotal'] = weather['PrecipTotal'].map(lambda x: 0.0 if x.strip() == 'T' else np.NaN if x == 'M' else float(x.strip()))

# %%
weather.PrecipTotal.unique()
# Out:
# array([0.  , 0.13, 0.02, 0.38, 0.6 , 0.14, 0.07, 0.11, 0.09, 1.01, 0.28,
#        0.04, 0.08, 0.01, 0.53, 0.19, 0.21, 0.32, 0.39, 0.31, 0.42, 0.27,
#        0.16, 0.58, 0.93, 0.05, 0.34, 0.15, 0.35,  nan, 0.4 , 0.66, 0.3 ,
#        0.24, 0.43, 1.55, 0.92, 0.89, 0.17, 0.03, 1.43, 0.97, 0.26, 1.31,
#        0.06, 0.46, 0.29, 0.23, 0.41, 0.45, 0.83, 1.33, 0.91, 0.48, 0.37,
#        0.88, 2.35, 1.96, 0.2 , 0.25, 0.18, 0.67, 0.36, 0.33, 1.28, 0.74,
#        0.76, 0.71, 0.95, 1.46, 0.12, 0.52, 0.64, 0.22, 1.24, 0.72, 0.73,
#        0.65, 1.61, 1.22, 0.5 , 1.05, 2.43, 0.59, 2.9 , 2.68, 1.23, 0.62,
#        6.64, 3.07, 1.44, 1.75, 0.82, 0.8 , 0.86, 0.63, 0.55, 1.03, 0.7 ,
#        1.73, 1.38, 0.44, 1.14, 1.07, 3.97, 0.87, 0.78, 1.12, 0.68, 0.1 ,
#        0.61, 0.54, 1.19, 0.75, 0.84, 1.29, 0.81, 1.15, 1.49, 1.57, 1.02,
#        1.3 , 0.51, 0.85, 0.79, 0.77, 2.79, 3.15, 3.64, 4.73, 1.6 , 0.57,
#        2.24, 1.9 , 1.06, 1.88, 0.69, 2.17, 6.86, 0.49, 1.11, 1.21, 0.9 ,
# ...

# %%
weather['PrecipTotal'].isnull().sum()
# Out:
# 2

# %%
weather.PrecipTotal.unique()
# Out:
# array([0.  , 0.13, 0.02, 0.38, 0.6 , 0.14, 0.07, 0.11, 0.09, 1.01, 0.28,
#        0.04, 0.08, 0.01, 0.53, 0.19, 0.21, 0.32, 0.39, 0.31, 0.42, 0.27,
#        0.16, 0.58, 0.93, 0.05, 0.34, 0.15, 0.35,  nan, 0.4 , 0.66, 0.3 ,
#        0.24, 0.43, 1.55, 0.92, 0.89, 0.17, 0.03, 1.43, 0.97, 0.26, 1.31,
#        0.06, 0.46, 0.29, 0.23, 0.41, 0.45, 0.83, 1.33, 0.91, 0.48, 0.37,
#        0.88, 2.35, 1.96, 0.2 , 0.25, 0.18, 0.67, 0.36, 0.33, 1.28, 0.74,
#        0.76, 0.71, 0.95, 1.46, 0.12, 0.52, 0.64, 0.22, 1.24, 0.72, 0.73,
#        0.65, 1.61, 1.22, 0.5 , 1.05, 2.43, 0.59, 2.9 , 2.68, 1.23, 0.62,
#        6.64, 3.07, 1.44, 1.75, 0.82, 0.8 , 0.86, 0.63, 0.55, 1.03, 0.7 ,
#        1.73, 1.38, 0.44, 1.14, 1.07, 3.97, 0.87, 0.78, 1.12, 0.68, 0.1 ,
#        0.61, 0.54, 1.19, 0.75, 0.84, 1.29, 0.81, 1.15, 1.49, 1.57, 1.02,
#        1.3 , 0.51, 0.85, 0.79, 0.77, 2.79, 3.15, 3.64, 4.73, 1.6 , 0.57,
#        2.24, 1.9 , 1.06, 1.88, 0.69, 2.17, 6.86, 0.49, 1.11, 1.21, 0.9 ,
# ...

# %%
# weather.dropna(axis = 1, subset = [], inplace = True)
weather.dropna(axis = 0, subset = ['PrecipTotal'])
# Out:
#       Station       Date  Tmax  Tmin  Tavg  DewPoint  WetBulb       Heat  \
# 0           1 2007-05-01    83    50  66.5        51     56.0   0.000000
# 1           2 2007-05-01    84    52  68.0        51     57.0   0.000000
# 2           1 2007-05-02    59    42  50.5        42     47.0  14.000000
# 3           2 2007-05-02    60    43  51.5        42     47.0  13.000000
# 4           1 2007-05-03    66    46  56.0        40     48.0   9.000000
# 5           2 2007-05-03    67    48  57.5        40     50.0   7.000000
# 6           1 2007-05-04    66    49  57.5        41     50.0   7.000000
# 7           2 2007-05-04    78    51  64.5        42     50.0   3.407092
# 8           1 2007-05-05    66    53  59.5        38     49.0   5.000000
# 9           2 2007-05-05    66    54  60.0        39     50.0   5.000000
# 10          1 2007-05-06    68    49  58.5        30     46.0   6.000000
# 11          2 2007-05-06    68    52  60.0        30     46.0   5.000000
# ...

# %%
weather = weather.applymap(lambda x: np.NaN if str(x) == 'M' else x)

# %%
weather.columns
# Out:
# Index([u'Station', u'Date', u'Tmax', u'Tmin', u'Tavg', u'DewPoint', u'WetBulb',
#        u'Heat', u'Cool', u'Sunrise', u'Sunset', u'CodeSum', u'Depth',
#        u'Water1', u'SnowFall', u'PrecipTotal', u'StnPressure', u'SeaLevel',
#        u'ResultSpeed', u'ResultDir', u'AvgSpeed', u'Month', u'Year', u'Dates'],
#       dtype='object')

# %%
weather['SnowFall'].unique()
# Out:
# array(['0.0', nan, '  T', '0.1'], dtype=object)

# %%
weather = weather.applymap(lambda x: 0. if str(x).strip() == 'T' else x)

# %%
weather['SnowFall'].unique()
# Out:
# array(['0.0', nan, 0.0, '0.1'], dtype=object)

# %%
weather[['SnowFall']] = weather[['SnowFall']].apply(pd.to_numeric)

# %%
weather.dtypes
# Out:
# Station                 int64
# Date           datetime64[ns]
# Tmax                    int64
# Tmin                    int64
# Tavg                  float64
# DewPoint                int64
# WetBulb               float64
# Heat                  float64
# Cool                  float64
# Sunrise                object
# Sunset                 object
# CodeSum                object
# Depth                  object
# Water1                float64
# SnowFall              float64
# PrecipTotal           float64
# StnPressure            object
# SeaLevel               object
# ResultSpeed           float64
# ResultDir               int64
# AvgSpeed               object
# Month                   int64
# Year                    int64
# Dates                  object
# dtype: object

# %%
weather.head()
# Out:
#    Station       Date  Tmax  Tmin  Tavg  DewPoint  WetBulb  Heat  Cool  \
# 0        1 2007-05-01    83    50  66.5        51     56.0   0.0   2.0
# 1        2 2007-05-01    84    52  68.0        51     57.0   0.0   3.0
# 2        1 2007-05-02    59    42  50.5        42     47.0  14.0   0.0
# 3        2 2007-05-02    60    43  51.5        42     47.0  13.0   0.0
# 4        1 2007-05-03    66    46  56.0        40     48.0   9.0   0.0
#
#   Sunrise     ...     SnowFall PrecipTotal StnPressure  SeaLevel  ResultSpeed  \
# 0    0448     ...          0.0         0.0       29.10     29.82          1.7
# 1       -     ...          NaN         0.0       29.18     29.82          2.7
# 2    0447     ...          0.0         0.0       29.38     30.09         13.0
# 3       -     ...          NaN         0.0       29.44     30.08         13.3
# 4    0446     ...          0.0         0.0       29.39     30.12         11.7
#
#    ResultDir AvgSpeed Month  Year       Dates
# ...

# %%
weather.drop(labels = 'Sunrise', axis= 1, inplace = True)

# %%
weather.drop(labels = 'Sunset', axis= 1, inplace = True)

# %%
weather.drop(labels = 'CodeSum', axis= 1, inplace = True)

# %%
weather.drop(labels = 'Depth', axis= 1, inplace = True)

# %%
weather.drop(labels = 'StnPressure', axis= 1, inplace = True)

# %%
weather.drop(labels = 'ResultSpeed', axis= 1, inplace = True)

# %%
weather.drop(labels = 'ResultDir', axis= 1, inplace = True)

# %%
weather.drop(labels = 'SeaLevel', axis= 1, inplace = True)

# %%
weather.drop(labels = 'AvgSpeed', axis= 1, inplace = True)
weather.drop(labels = 'Dates', axis= 1, inplace = True)
weather.drop(labels = 'Water1', axis= 1, inplace = True)
weather.drop(labels = 'SnowFall', axis= 1, inplace = True)

# %%
weather.head()
# Out:
#    Station       Date  Tmax  Tmin  Tavg  DewPoint  WetBulb  Heat  Cool  \
# 0        1 2007-05-01    83    50  66.5        51     56.0   0.0   2.0
# 1        2 2007-05-01    84    52  68.0        51     57.0   0.0   3.0
# 2        1 2007-05-02    59    42  50.5        42     47.0  14.0   0.0
# 3        2 2007-05-02    60    43  51.5        42     47.0  13.0   0.0
# 4        1 2007-05-03    66    46  56.0        40     48.0   9.0   0.0
#
#    PrecipTotal  Month  Year
# 0          0.0      5  2007
# 1          0.0      5  2007
# 2          0.0      5  2007
# 3          0.0      5  2007
# 4          0.0      5  2007

# %%
weather.dtypes
# Out:
# Station                 int64
# Date           datetime64[ns]
# Tmax                    int64
# Tmin                    int64
# Tavg                  float64
# DewPoint                int64
# WetBulb               float64
# Heat                  float64
# Cool                  float64
# PrecipTotal           float64
# Month                   int64
# Year                    int64
# dtype: object

# %%
# weather.to_csv('./datasets')
weather.to_csv(w, sep='\t')
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-74-cfb41ae394e3> in <module>()
# ----> 1 weather.to_csv('./datasets')
#
# C:\Users\hafsa\Anaconda2\lib\site-packages\pandas\core\frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# C:\Users\hafsa\Anaconda2\lib\site-packages\pandas\io\formats\format.pyc in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
# ...
